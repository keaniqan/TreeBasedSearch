# %% [markdown]
# Importing the required libraries and constants

# %%
import os, pathlib, json, numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import f1_score

SEED = 42
IMG_SIZE = (224, 224)
BATCH = 32

ROOT_DIR = pathlib.Path("data/")
TRAIN_DIR = ROOT_DIR / "training"
VAL_DIR   = ROOT_DIR / "validation"
TEST_DIR  = ROOT_DIR / "testing"

TRAIN_SPLIT = 0.8
VAL_SPLIT   = 0.1
TEST_SPLIT  = 0.1

MODEL_DIR = "models"

# %% [markdown]
# Distribute the images to create training, validation and testing sets

# %%
# import shutil
# from collections import defaultdict

# np.random.seed(SEED )
# # Gather all images by class from all splits
# all_images = defaultdict(list)
# for split_dir in [TRAIN_DIR, VAL_DIR, TEST_DIR]:
#     for class_dir in split_dir.iterdir():
#         if class_dir.is_dir():
#             for img_file in class_dir.glob("*.jpg"):
#                 all_images[class_dir.name].append(img_file)
#             for img_file in class_dir.glob("*.png"):
#                 all_images[class_dir.name].append(img_file)
#             for img_file in class_dir.glob("*.jpeg"):
#                 all_images[class_dir.name].append(img_file)

# # Redistribute according to split ratios
# for class_name, img_files in all_images.items():
#     img_files = np.array(img_files)
#     np.random.shuffle(img_files)
#     n_total = len(img_files)
#     n_train = int(n_total * TRAIN_SPLIT)
#     n_val = int(n_total * VAL_SPLIT)
#     n_test = n_total - n_train - n_val

#     splits = [
#         (TRAIN_DIR / class_name, img_files[:n_train]),
#         (VAL_DIR / class_name, img_files[n_train:n_train+n_val]),
#         (TEST_DIR / class_name, img_files[n_train+n_val:]),
#     ]

#     for target_dir, files in splits:
#         target_dir.mkdir(parents=True, exist_ok=True)
#         for f in files:
#             dest = target_dir / f.name
#             if f.resolve() != dest.resolve():
#                 shutil.move(str(f), str(dest))

# print("Data redistribution complete.")
# # Print out number of images in each split for each class
# for class_name in all_images.keys():
#     train_count = len(list((TRAIN_DIR / class_name).glob("*.jpg"))) + len(list((TRAIN_DIR / class_name).glob("*.png"))) + len(list((TRAIN_DIR / class_name).glob("*.jpeg")))
#     val_count = len(list((VAL_DIR / class_name).glob("*.jpg"))) + len(list((VAL_DIR / class_name).glob("*.png"))) + len(list((VAL_DIR / class_name).glob("*.jpeg")))
#     test_count = len(list((TEST_DIR / class_name).glob("*.jpg"))) + len(list((TEST_DIR / class_name).glob("*.png"))) + len(list((TEST_DIR / class_name).glob("*.jpeg")))
#     print(f"Class '{class_name}': Training={train_count}, Validation={val_count}, Testing={test_count}")

# %% [markdown]
# This file is for training the various image classification models

# %%
import tensorflow as tf
from tensorflow import keras

# Build datasets WITHOUT validation_split
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH,
    shuffle=True
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH,
    shuffle=False   # keep order stable for metrics/plots
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH,
    shuffle=False   # keep order stable for metrics/plots
)

# Class names (e.g., ['01-minor','02-moderate','03-severe'])
class_names = train_ds.class_names
NUM_CLASSES = len(class_names)
print("Classes:", class_names)

# (Optional) pretty labels for display, stripping the numeric prefixes
pretty_names = [c.split('-', 1)[-1] if '-' in c else c for c in class_names]

AUTOTUNE = tf.data.AUTOTUNE
def configure(ds, training=False):
    ds = ds.cache()
    if training:
        ds = ds.shuffle(1024, seed=SEED)
    return ds.prefetch(AUTOTUNE)

train_ds = configure(train_ds, training=True)
val_ds   = configure(val_ds)
test_ds  = configure(test_ds)
# Out:
# Found 2035 files belonging to 4 classes.
# Found 253 files belonging to 4 classes.
# Found 258 files belonging to 4 classes.
# Classes: ['00-none', '01-minor', '02-moderate', '03-severe']

# %% [markdown]
# Setting up F1 function for performance evaluation

# %%
import numpy as np
from sklearn.metrics import f1_score

class MacroF1Callback(keras.callbacks.Callback):
    def __init__(self, val_ds, num_classes):
        super().__init__()
        self.val_ds = val_ds
        self.num_classes = num_classes

    def on_epoch_end(self, epoch, logs=None):
        y_true = []
        y_pred = []
        for xb, yb in self.val_ds:
            probs = self.model.predict(xb, verbose=0)
            y_pred.extend(np.argmax(probs, axis=1))
            # yb may be ints or one-hot depending on your pipeline:
            if yb.ndim == 2:  # one-hot
                y_true.extend(np.argmax(yb.numpy(), axis=1))
            else:             # integer labels
                y_true.extend(yb.numpy())
        y_true = np.array(y_true)
        y_pred = np.array(y_pred)
        macro_f1 = f1_score(y_true, y_pred, average="macro")
        logs = logs or {}
        logs["val_macro_f1"] = macro_f1
        print(f"\nval_macro_f1: {macro_f1:.4f}")

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.08),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
], name="augment")

preprocess = keras.applications.resnet50.preprocess_input

base = keras.applications.resnet50.ResNet50(
    include_top=False, weights="imagenet", input_shape=(*IMG_SIZE, 3)
)
base.trainable = False

inputs = keras.Input(shape=(*IMG_SIZE, 3))
x = data_augmentation(inputs)
x = preprocess(x)
x = base(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ augment             │ (None, 224, 224,  │          0 │ input_layer_1[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 224, 224)  │          0 │ augment[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 224, 224)  │          0 │ augment[0][0]     │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 224, 224)  │          0 │ augment[0][0]     │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack (Stack)       │ (None, 224, 224,  │          0 │ get_item[0][0],   │
# │                     │ 3)                │            │ get_item_1[0][0], │
# │                     │                   │            │ get_item_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 224, 224,  │          0 │ stack[0][0]       │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50            │ (None, 7, 7,      │ 23,587,712 │ add[0][0]         │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ resnet50[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 2048)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 4)         │      8,196 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,595,908 (90.01 MB)
#  Trainable params: 8,196 (32.02 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# # 5. Training with Checkpoint
#
# Early stopping with checkpoint. we start with frozen and then unlock the model. GPU enabled runtime will run much faster. If you plot the curves what can it tell you on the epochs?

# %%
EPOCHS_FROZEN = 30
EPOCHS_FINE   = 60

model.compile(
    optimizer=keras.optimizers.Adam(3e-4),
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=[keras.metrics.CategoricalAccuracy(name="acc")]
)

# If your datasets are integer labels, map to one-hot for this loss:
train_oh = train_ds.map(lambda x, y: (x, tf.one_hot(y, NUM_CLASSES)))
val_oh   = val_ds.map(lambda x, y: (x, tf.one_hot(y, NUM_CLASSES)))

f1_cb = MacroF1Callback(val_ds, NUM_CLASSES)

#Model filename
filename = MODEL_DIR + "\\resnet_frozen.keras"

ckpt1 = keras.callbacks.ModelCheckpoint(
    filename, monitor="val_macro_f1", mode="max",
    save_best_only=True, verbose=1
)
early = keras.callbacks.EarlyStopping(monitor="val_macro_f1", mode="max",
                                      patience=5, restore_best_weights=True)
reduce = keras.callbacks.ReduceLROnPlateau(monitor="val_loss",
                                           factor=0.5, patience=2, verbose=1)

hist1 = model.fit(
    train_oh, validation_data=val_oh,
    epochs=EPOCHS_FROZEN, callbacks=[f1_cb, ckpt1, early, reduce], verbose=2
)
# Out:
# Epoch 1/30
#
# val_macro_f1: 0.4643
#
# Epoch 1: val_macro_f1 improved from None to 0.46434, saving model to models\resnet_frozen.keras
# 64/64 - 118s - 2s/step - acc: 0.3725 - loss: 1.4319 - val_acc: 0.4783 - val_loss: 1.1826 - val_macro_f1: 0.4643 - learning_rate: 3.0000e-04
# Epoch 2/30
#
# val_macro_f1: 0.5252
#
# Epoch 2: val_macro_f1 improved from 0.46434 to 0.52522, saving model to models\resnet_frozen.keras
# 64/64 - 103s - 2s/step - acc: 0.5287 - loss: 1.1617 - val_acc: 0.5375 - val_loss: 1.0775 - val_macro_f1: 0.5252 - learning_rate: 3.0000e-04
# Epoch 3/30
#
# val_macro_f1: 0.6212
#
# Epoch 3: val_macro_f1 improved from 0.52522 to 0.62116, saving model to models\resnet_frozen.keras
# 64/64 - 115s - 2s/step - acc: 0.5936 - loss: 1.0443 - val_acc: 0.6324 - val_loss: 0.9684 - val_macro_f1: 0.6212 - learning_rate: 3.0000e-04
# Epoch 4/30
#
# val_macro_f1: 0.6338
#
# Epoch 4: val_macro_f1 improved from 0.62116 to 0.63377, saving model to models\resnet_frozen.keras
# 64/64 - 111s - 2s/step - acc: 0.6216 - loss: 0.9778 - val_acc: 0.6403 - val_loss: 0.9247 - val_macro_f1: 0.6338 - learning_rate: 3.0000e-04
# Epoch 5/30
#
# val_macro_f1: 0.6436
#
# Epoch 5: val_macro_f1 improved from 0.63377 to 0.64359, saving model to models\resnet_frozen.keras
# 64/64 - 113s - 2s/step - acc: 0.6251 - loss: 0.9652 - val_acc: 0.6482 - val_loss: 0.9099 - val_macro_f1: 0.6436 - learning_rate: 3.0000e-04
# Epoch 6/30
#
# val_macro_f1: 0.6486
#
# Epoch 6: val_macro_f1 improved from 0.64359 to 0.64855, saving model to models\resnet_frozen.keras
# 64/64 - 109s - 2s/step - acc: 0.6491 - loss: 0.9220 - val_acc: 0.6601 - val_loss: 0.8844 - val_macro_f1: 0.6486 - learning_rate: 3.0000e-04
# Epoch 7/30
#
# val_macro_f1: 0.6313
#
# Epoch 7: val_macro_f1 did not improve from 0.64855
# 64/64 - 105s - 2s/step - acc: 0.6585 - loss: 0.8971 - val_acc: 0.6443 - val_loss: 0.8742 - val_macro_f1: 0.6313 - learning_rate: 3.0000e-04
# Epoch 8/30
#
# val_macro_f1: 0.6415
#
# Epoch 8: val_macro_f1 did not improve from 0.64855
# 64/64 - 106s - 2s/step - acc: 0.6516 - loss: 0.8949 - val_acc: 0.6403 - val_loss: 0.8767 - val_macro_f1: 0.6415 - learning_rate: 3.0000e-04
# Epoch 9/30
#
# val_macro_f1: 0.6627
#
# Epoch 9: val_macro_f1 improved from 0.64855 to 0.66274, saving model to models\resnet_frozen.keras
# 64/64 - 112s - 2s/step - acc: 0.6919 - loss: 0.8542 - val_acc: 0.6680 - val_loss: 0.8538 - val_macro_f1: 0.6627 - learning_rate: 3.0000e-04
# Epoch 10/30
#
# val_macro_f1: 0.6488
#
# Epoch 10: val_macro_f1 did not improve from 0.66274
# 64/64 - 107s - 2s/step - acc: 0.6806 - loss: 0.8502 - val_acc: 0.6640 - val_loss: 0.8620 - val_macro_f1: 0.6488 - learning_rate: 3.0000e-04
# Epoch 11/30
#
# val_macro_f1: 0.6538
#
# Epoch 11: val_macro_f1 did not improve from 0.66274
# 64/64 - 107s - 2s/step - acc: 0.7007 - loss: 0.8349 - val_acc: 0.6561 - val_loss: 0.8467 - val_macro_f1: 0.6538 - learning_rate: 3.0000e-04
# Epoch 12/30
#
# val_macro_f1: 0.6594
#
# Epoch 12: val_macro_f1 did not improve from 0.66274
# 64/64 - 104s - 2s/step - acc: 0.7012 - loss: 0.8227 - val_acc: 0.6601 - val_loss: 0.8377 - val_macro_f1: 0.6594 - learning_rate: 3.0000e-04
# Epoch 13/30
#
# val_macro_f1: 0.6622
#
# Epoch 13: val_macro_f1 did not improve from 0.66274
# 64/64 - 105s - 2s/step - acc: 0.6968 - loss: 0.8137 - val_acc: 0.6680 - val_loss: 0.8508 - val_macro_f1: 0.6622 - learning_rate: 3.0000e-04
# Epoch 14/30
#
# val_macro_f1: 0.6507
#
# Epoch 14: val_macro_f1 did not improve from 0.66274
# 64/64 - 96s - 2s/step - acc: 0.7061 - loss: 0.8042 - val_acc: 0.6522 - val_loss: 0.8190 - val_macro_f1: 0.6507 - learning_rate: 3.0000e-04

# %% [markdown]
# 6. Unfreeze (Fine Tuning)

# %%
# Unfreeze top layers except BatchNorm
for layer in base.layers[-60:]:
    if not isinstance(layer, layers.BatchNormalization):
        layer.trainable = True

model.compile(
    optimizer=keras.optimizers.Adam(1e-5),
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=[keras.metrics.CategoricalAccuracy(name="acc")]
)

filename = MODEL_DIR + "\\resnet_finetuned.keras"
f1_cb2 = MacroF1Callback(val_ds, NUM_CLASSES)
ckpt2 = keras.callbacks.ModelCheckpoint(
    filename, monitor="val_macro_f1", mode="max",
    save_best_only=True, verbose=1
)

hist2 = model.fit(
    train_oh, validation_data=val_oh,
    epochs=EPOCHS_FINE, callbacks=[f1_cb2, ckpt2, early, reduce], verbose=2
)
# Out:
# Epoch 1/60
#
# val_macro_f1: 0.6571
#
# Epoch 1: val_macro_f1 improved from None to 0.65707, saving model to models\resnet_finetuned.keras
# 64/64 - 197s - 3s/step - acc: 0.6865 - loss: 0.8387 - val_acc: 0.6601 - val_loss: 0.8519 - val_macro_f1: 0.6571 - learning_rate: 1.0000e-05
# Epoch 2/60
#
# val_macro_f1: 0.6548
#
# Epoch 2: val_macro_f1 did not improve from 0.65707
#
# Epoch 2: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 64/64 - 117s - 2s/step - acc: 0.7115 - loss: 0.7874 - val_acc: 0.6522 - val_loss: 0.8246 - val_macro_f1: 0.6548 - learning_rate: 1.0000e-05
# Epoch 3/60
#
# val_macro_f1: 0.6839
#
# Epoch 3: val_macro_f1 improved from 0.65707 to 0.68392, saving model to models\resnet_finetuned.keras
# 64/64 - 154s - 2s/step - acc: 0.7400 - loss: 0.7312 - val_acc: 0.6838 - val_loss: 0.8020 - val_macro_f1: 0.6839 - learning_rate: 5.0000e-06
# Epoch 4/60
#
# val_macro_f1: 0.7038
#
# Epoch 4: val_macro_f1 improved from 0.68392 to 0.70376, saving model to models\resnet_finetuned.keras
# 64/64 - 146s - 2s/step - acc: 0.7572 - loss: 0.6968 - val_acc: 0.7036 - val_loss: 0.7860 - val_macro_f1: 0.7038 - learning_rate: 5.0000e-06
# Epoch 5/60
#
# val_macro_f1: 0.6845
#
# Epoch 5: val_macro_f1 did not improve from 0.70376
# 64/64 - 137s - 2s/step - acc: 0.7720 - loss: 0.6793 - val_acc: 0.6838 - val_loss: 0.8107 - val_macro_f1: 0.6845 - learning_rate: 5.0000e-06
# Epoch 6/60
#
# val_macro_f1: 0.6813
#
# Epoch 6: val_macro_f1 did not improve from 0.70376
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 64/64 - 121s - 2s/step - acc: 0.7774 - loss: 0.6637 - val_acc: 0.6798 - val_loss: 0.8099 - val_macro_f1: 0.6813 - learning_rate: 5.0000e-06
# Epoch 7/60
#
# val_macro_f1: 0.6930
#
# Epoch 7: val_macro_f1 did not improve from 0.70376
# 64/64 - 146s - 2s/step - acc: 0.8034 - loss: 0.6442 - val_acc: 0.6917 - val_loss: 0.7978 - val_macro_f1: 0.6930 - learning_rate: 2.5000e-06
# Epoch 8/60
#
# val_macro_f1: 0.7113
#
# Epoch 8: val_macro_f1 improved from 0.70376 to 0.71133, saving model to models\resnet_finetuned.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 64/64 - 165s - 3s/step - acc: 0.7975 - loss: 0.6298 - val_acc: 0.7115 - val_loss: 0.7923 - val_macro_f1: 0.7113 - learning_rate: 2.5000e-06
# Epoch 9/60
#
# val_macro_f1: 0.7113
#
# Epoch 9: val_macro_f1 did not improve from 0.71133
# 64/64 - 155s - 2s/step - acc: 0.8074 - loss: 0.6190 - val_acc: 0.7075 - val_loss: 0.7941 - val_macro_f1: 0.7113 - learning_rate: 1.2500e-06
# Epoch 10/60
#
# val_macro_f1: 0.7011
#
# Epoch 10: val_macro_f1 did not improve from 0.71133
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
# 64/64 - 154s - 2s/step - acc: 0.8108 - loss: 0.6113 - val_acc: 0.6996 - val_loss: 0.7953 - val_macro_f1: 0.7011 - learning_rate: 1.2500e-06
# Epoch 11/60
#
# val_macro_f1: 0.6983
#
# Epoch 11: val_macro_f1 did not improve from 0.71133
# 64/64 - 141s - 2s/step - acc: 0.8059 - loss: 0.6157 - val_acc: 0.6996 - val_loss: 0.8021 - val_macro_f1: 0.6983 - learning_rate: 6.2500e-07
# Epoch 12/60
#
# val_macro_f1: 0.7020
#
# Epoch 12: val_macro_f1 did not improve from 0.71133
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
# 64/64 - 146s - 2s/step - acc: 0.8182 - loss: 0.6046 - val_acc: 0.6996 - val_loss: 0.7953 - val_macro_f1: 0.7020 - learning_rate: 6.2500e-07
# Epoch 13/60
#
# val_macro_f1: 0.7055
#
# Epoch 13: val_macro_f1 did not improve from 0.71133
# 64/64 - 147s - 2s/step - acc: 0.8290 - loss: 0.5909 - val_acc: 0.7036 - val_loss: 0.7924 - val_macro_f1: 0.7055 - learning_rate: 3.1250e-07

# %% [markdown]
# 7. Performance Evaluation
# there are also other things to show. can you think of any?

# %%
from sklearn.metrics import classification_report, confusion_matrix
MODEL_FILE = MODEL_DIR + "\\resnet_finetuned.keras"

best = keras.models.load_model(MODEL_FILE, compile=False)
best.compile(optimizer=keras.optimizers.Adam(1e-5),
             loss=keras.losses.CategoricalCrossentropy(),
             metrics=["accuracy"])

y_true, y_pred = [], []
for xb, yb in test_ds:
    probs = best.predict(xb, verbose=0)
    y_pred.extend(np.argmax(probs, axis=1))
    if yb.ndim == 2: y_true.extend(np.argmax(yb.numpy(), axis=1))
    else:            y_true.extend(yb.numpy())

y_true = np.array(y_true)
y_pred = np.array(y_pred)

print("Confusion matrix:\n", confusion_matrix(y_true, y_pred))
print("\nClassification report:")
print(classification_report(y_true, y_pred, target_names=class_names))
print("Macro-F1:", f1_score(y_true, y_pred, average="macro"))
# Out:
# Confusion matrix:
#  [[64  2  4  1]
#  [ 3 42  5  0]
#  [ 9 13 31 14]
#  [ 2  3 21 44]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#      00-none       0.82      0.90      0.86        71
#     01-minor       0.70      0.84      0.76        50
#  02-moderate       0.51      0.46      0.48        67
#    03-severe       0.75      0.63      0.68        70
#
#     accuracy                           0.70       258
#    macro avg       0.69      0.71      0.70       258
# weighted avg       0.70      0.70      0.70       258
#
# Macro-F1: 0.6973105772391466

# %%
import matplotlib.pyplot as plt
import random
MODEL_FILE = MODEL_DIR + "\\resnet_finetuned.keras"

# Create a dataset with raw images and labels (no one-hot)
val_raw = tf.keras.utils.image_dataset_from_directory(
    ROOT_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH,
    validation_split=0.1,
    subset="validation",
    shuffle=True
)

# Get a small batch
images, labels = next(iter(val_raw))
pred_probs = best.predict(images)
pred_ids = np.argmax(pred_probs, axis=1)
true_ids = labels.numpy()

# Plot 12 random samples
plt.figure(figsize=(12, 9))
for i, idx in enumerate(random.sample(range(len(images)), 12)):
    ax = plt.subplot(3, 4, i + 1)
    img = images[idx].numpy().astype("uint8")
    true_label = class_names[true_ids[idx]]
    pred_label = class_names[pred_ids[idx]]
    color = "green" if pred_label == true_label else "red"
    plt.imshow(img)
    plt.title(f"Pred: {pred_label}\nTrue: {true_label}", color=color, fontsize=9)
    plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# Found 7626 files belonging to 6 classes.
# Using 762 files for validation.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 27
#      25 ax = plt.subplot(3, 4, i + 1)
#      26 img = images[idx].numpy().astype("uint8")
# ---> 27 true_label = class_names[true_ids[idx]]
#      28 pred_label = class_names[pred_ids[idx]]
#      29 color = "green" if pred_label == true_label else "red"
#
# IndexError: list index out of range
